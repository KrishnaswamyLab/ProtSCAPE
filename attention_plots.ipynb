# %%
import pickle as pk
import numpy as np
#3 attention heads and 3 layers
# attention_maps = np.load('/home/sv496/project/ProGSNN-1/train_logs/progsnn_logs_run_deshaw_2024-01-18-16/attention_maps.npy')
#1 attention head and 1 layer
with open('attention_residue_10.pkl', 'rb') as file:
    # Load the data from the pickle file
    attention_maps = pk.load(file)

# %%
len(attention_maps)
# Out:
# 100

# %%
attention_maps[0].shape
# Out:
# torch.Size([100, 1, 660, 660])

# %%
attention_maps = [i.mean(axis = 0) for i in attention_maps]

# %%
attention_maps[0].shape
# Out:
# torch.Size([1, 660, 660])

# %%
attention_maps[1][0]
# Out:
# tensor([[4.7308e-06, 4.0775e-06, 5.1621e-06,  ..., 3.3709e-04, 2.7679e-04,
#          1.9093e-04],
#         [3.3224e-06, 2.8298e-06, 3.6652e-06,  ..., 2.8723e-04, 2.3043e-04,
#          1.5466e-04],
#         [2.7394e-06, 2.3046e-06, 3.0702e-06,  ..., 2.4466e-04, 1.9567e-04,
#          1.2903e-04],
#         ...,
#         [1.3104e-05, 1.1527e-05, 1.5196e-05,  ..., 3.9859e-04, 3.0049e-04,
#          2.1790e-04],
#         [1.1212e-05, 9.6801e-06, 1.2466e-05,  ..., 3.7629e-04, 2.8715e-04,
#          2.0865e-04],
#         [8.6072e-06, 7.3433e-06, 9.4584e-06,  ..., 3.1779e-04, 2.3930e-04,
#          1.6975e-04]])

# %%
import seaborn as sns
sns.heatmap(attention_maps[0][0], cmap='viridis')
# Out:
# <Axes: >

# %%
sns.heatmap(attention_maps[0], cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sns.heatmap(attention_maps[0], cmap='viridis')
#
# NameError: name 'sns' is not defined
